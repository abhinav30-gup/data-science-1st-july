# %%
import pandas as pd

# %%
df=pd.read_csv("laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df=pd.read_csv(r"C:\Users\abhin\OneDrive\Desktop\ds 1st july\data-science-1st-july\pandas\laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 21

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     802.000000          802.00000         802.000000
# mean    76625.543641          299.84414          36.089776
# std     45232.984422         1001.78442         118.313553
# min     16990.000000            0.00000           0.000000
# 25%     45990.000000            0.00000           0.000000
# 50%     63990.000000           17.00000           2.000000
# 75%     89525.000000          140.25000          18.000000
# max    441990.000000        15279.00000        1947.000000

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.head(10)
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
df.tail(10)
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 813    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 814    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 815    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 816    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 817    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# ...

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
df.brand
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 802, dtype: object

# %%
df.Price
# Out:
# 0       34649
# 1       38999
# 2       39999
# 3       69990
# 4       26990
#         ...
# 818    135990
# 819    144990
# 820    149990
# 821    142990
# 822     57490
# Name: Price, Length: 802, dtype: int64

# %%
df['processor_brand']
# Out:
# 0      Intel
# 1      Intel
# 2      Intel
# 3      Intel
# 4      Intel
#        ...
# 818      AMD
# 819      AMD
# 820      AMD
# 821      AMD
# 822      AMD
# Name: processor_brand, Length: 802, dtype: object

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# Intel    594
# AMD      189
# M1        19
# Name: count, dtype: int64

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
df['processor_brand'].nunique()
# Out:
# 3

# %%
df.shape
# Out:
# (802, 19)

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df[df['brand']=='ASUS']
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
asus_df= df[df['brand']=='ASUS']

# %%
asus_df
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
asus_df= df[df['ram_gb']=='4 GB']
asus_df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 817    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
# ...

# %%
asus_df= df[df['processor_name']=='Ryzen 9']
asus_df
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 796  ASUS             AMD        Ryzen 9   Not Available  16 GB     DDR4
# 797  ASUS             AMD        Ryzen 9   Not Available  16 GB     DDR4
# 798  ASUS             AMD        Ryzen 9   Not Available  16 GB     DDR4
# 799  ASUS             AMD        Ryzen 9   Not Available  16 GB     DDR4
# 800  ASUS             AMD        Ryzen 9   Not Available  16 GB     DDR4
# 801  ASUS             AMD        Ryzen 9   Not Available  16 GB  LPDDR4X
# 802   MSI             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 803  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 804  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 805  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 806  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 807    HP             AMD        Ryzen 9   Not Available   4 GB     DDR4
# ...

# %%
asus_price_df=asus_df[asus_df['Price']<=150000]
asus_price_df
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 796  ASUS             AMD        Ryzen 9   Not Available  16 GB     DDR4
# 799  ASUS             AMD        Ryzen 9   Not Available  16 GB     DDR4
# 800  ASUS             AMD        Ryzen 9   Not Available  16 GB     DDR4
# 801  ASUS             AMD        Ryzen 9   Not Available  16 GB  LPDDR4X
# 802   MSI             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 803  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 804  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 805  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 806  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 807    HP             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 808  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 809  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# ...

# %%
asus_df =df[(df['brand']=='ASUS')&
    (df['ram_gb']== '4 GB')&
    (df['processor_name']=='Ryzen 9')&
    (df['Price']<=150000)]

# %%
asus_df
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 803  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 804  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 805  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 806  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 808  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 809  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 810  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 811  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 812  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 814  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 815  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 816  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# ...

# %%
df.query('brand == "ASUS" and ram_gb == "4 GB" and processor_name == "Ryzen 9" and Price <= 150000')
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 803  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 804  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 805  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 806  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 808  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 809  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 810  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 811  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 812  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 814  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 815  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 816  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# ...

# %%
df.rename(columns={'ram_gb': 'ram'}, inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn   ram ram_type  \
# 0      ASUS           Intel        Core i3            10th  4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th  4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th  4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th  8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available  4 GB     DDR4
# ..      ...             ...            ...             ...   ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available  4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th  8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df.rename(columns={'processor_name': 'processor'}, inplace=True)

# %%
df
# Out:
#       brand processor_brand     processor processor_gnrtn   ram ram_type  \
# 0      ASUS           Intel       Core i3            10th  4 GB     DDR4
# 1    Lenovo           Intel       Core i3            10th  4 GB     DDR4
# 2    Lenovo           Intel       Core i3            10th  4 GB     DDR4
# 3      ASUS           Intel       Core i5            10th  8 GB     DDR4
# 4      ASUS           Intel  Celeron Dual   Not Available  4 GB     DDR4
# ..      ...             ...           ...             ...   ...      ...
# 818    ASUS             AMD       Ryzen 9   Not Available  4 GB     DDR4
# 819    ASUS             AMD       Ryzen 9   Not Available  4 GB     DDR4
# 820    ASUS             AMD       Ryzen 9   Not Available  4 GB     DDR4
# 821    ASUS             AMD       Ryzen 9   Not Available  4 GB     DDR4
# 822  Lenovo             AMD       Ryzen 5            10th  8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df.drop(columns=['ram_type','Touchscreen','weight'], axis=1,inplace=True)

# %%
df
# Out:
#       brand processor_brand     processor processor_gnrtn   ram      ssd  \
# 0      ASUS           Intel       Core i3            10th  4 GB     0 GB
# 1    Lenovo           Intel       Core i3            10th  4 GB     0 GB
# 2    Lenovo           Intel       Core i3            10th  4 GB     0 GB
# 3      ASUS           Intel       Core i5            10th  8 GB   512 GB
# 4      ASUS           Intel  Celeron Dual   Not Available  4 GB     0 GB
# ..      ...             ...           ...             ...   ...      ...
# 818    ASUS             AMD       Ryzen 9   Not Available  4 GB  1024 GB
# 819    ASUS             AMD       Ryzen 9   Not Available  4 GB  1024 GB
# 820    ASUS             AMD       Ryzen 9   Not Available  4 GB  1024 GB
# 821    ASUS             AMD       Ryzen 9   Not Available  4 GB  1024 GB
# 822  Lenovo             AMD       Ryzen 5            10th  8 GB   512 GB
#
#          hdd       os  os_bit graphic_card_gb     warranty msoffice   Price  \
# ...

# %%
df.to_csv('Cleaned_laptop_Price.csv', index=False)

# %%
num=df.select_dtypes(exclude='object')

# %%
num
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [802 rows x 3 columns]

# %%
char=df.select_dtypes(include='object')

# %%
char['processor'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
char
# Out:
#       brand processor_brand     processor processor_gnrtn   ram      ssd  \
# 0      ASUS           Intel       Core i3            10th  4 GB     0 GB
# 1    Lenovo           Intel       Core i3            10th  4 GB     0 GB
# 2    Lenovo           Intel       Core i3            10th  4 GB     0 GB
# 3      ASUS           Intel       Core i5            10th  8 GB   512 GB
# 4      ASUS           Intel  Celeron Dual   Not Available  4 GB     0 GB
# ..      ...             ...           ...             ...   ...      ...
# 818    ASUS             AMD       Ryzen 9   Not Available  4 GB  1024 GB
# 819    ASUS             AMD       Ryzen 9   Not Available  4 GB  1024 GB
# 820    ASUS             AMD       Ryzen 9   Not Available  4 GB  1024 GB
# 821    ASUS             AMD       Ryzen 9   Not Available  4 GB  1024 GB
# 822  Lenovo             AMD       Ryzen 5            10th  8 GB   512 GB
#
#          hdd       os  os_bit graphic_card_gb     warranty msoffice   rating
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()  #used to create an instance of the LabelEncoder class
char['brand'] = le.fit_transform(char['brand'])  #used to encode the brand column with numerical values
char['processor'] = le.fit_transform(char['processor'])  #used to encode the processor column with numerical values
char['processor_brand'] = le.fit_transform(char['processor_brand'])  #used to encode the processor_brand column with numerical values
char['os'] = le.fit_transform(char['os'])  #used to encode the os column with numerical values
char['os_bit'] = le.fit_transform(char['os_bit'])  #used to encode the os column with numerical values
char['processor_gnrtn'] = le.fit_transform(char['processor_gnrtn'])  #used to encode the processor_generation column with numerical values
char['ram'] = le.fit_transform(char['ram'])  #used to encode the ram
char['ssd'] = le.fit_transform(char['ssd'])  #used to encode the ssd column with numerical values
char['warranty'] = le.fit_transform(char['warranty'])  #used to encode the warrenty column with numerical values
char['hdd'] = le.fit_transform(char['hdd'])  #used to encode the hdd column with numerical values
char['msoffice'] = le.fit_transform(char['msoffice'])  #used to encode the hdd column with numerical values
char['rating'] = le.fit_transform(char['rating'])  #used to encode the hdd column with numerical values
char['graphic_card_gb'] = le.fit_transform(char['graphic_card_gb'])  #used to encode graphic_card_gb column with numerical values

# %%
num
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [802 rows x 3 columns]

# %%
char
# Out:
#      brand  processor_brand  processor  processor_gnrtn  ram  ssd  hdd  os  \
# 0        1                1          1                0    2    0    1   2
# 1        5                1          1                0    2    0    1   2
# 2        5                1          1                0    2    0    1   2
# 3        1                1          2                0    3    6    0   2
# 4        1                1          0                7    2    0    3   2
# ..     ...              ...        ...              ...  ...  ...  ...  ..
# 818      1                0         10                7    2    1    0   2
# 819      1                0         10                7    2    1    0   2
# 820      1                0         10                7    2    1    0   2
# 821      1                0         10                7    2    1    0   2
# 822      5                0          8                0    3    6    0   0
#
#      os_bit  graphic_card_gb  warranty  msoffice  rating
# ...

# %%
char['brand'].unique()
# Out:
# array([1, 5, 7, 2, 4, 3, 6, 0], dtype=int64)

# %%
clean_data=pd.concat([char,num],axis=1)

# %%
clean_data
# Out:
#      brand  processor_brand  processor  processor_gnrtn  ram  ssd  hdd  os  \
# 0        1                1          1                0    2    0    1   2
# 1        5                1          1                0    2    0    1   2
# 2        5                1          1                0    2    0    1   2
# 3        1                1          2                0    3    6    0   2
# 4        1                1          0                7    2    0    3   2
# ..     ...              ...        ...              ...  ...  ...  ...  ..
# 818      1                0         10                7    2    1    0   2
# 819      1                0         10                7    2    1    0   2
# 820      1                0         10                7    2    1    0   2
# 821      1                0         10                7    2    1    0   2
# 822      5                0          8                0    3    6    0   0
#
#      os_bit  graphic_card_gb  warranty  msoffice  rating   Price  \
# ...

# %%
clean_data.to_csv('new_Cleaned_laptop_Price.csv', index=False)

# %% [markdown]
# ## insurance.csv

# %%
df=pd.read_csv("insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.tail(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.age
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1337, dtype: int64

# %%
df['sex']
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: sex, Length: 1337, dtype: object

# %%
df['children'].value_counts()
# Out:
# children
# 0    573
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
df['bmi'].unique
# Out:
# <bound method Series.unique of 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1337, dtype: float64>

# %%
df['region'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1337, dtype: object>

# %%
df.shape
# Out:
# (1337, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df['sex'] == 'male'
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1333     True
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Name: sex, Length: 1337, dtype: bool

# %%
df[df['sex'] == 'male']
# Out:
#       age   sex     bmi  children smoker     region      charges
# 1      18  male  33.770         1     no  southeast   1725.55230
# 2      28  male  33.000         3     no  southeast   4449.46200
# 3      33  male  22.705         0     no  northwest  21984.47061
# 4      32  male  28.880         0     no  northwest   3866.85520
# 8      37  male  29.830         2     no  northeast   6406.41070
# ...   ...   ...     ...       ...    ...        ...          ...
# 1324   31  male  25.935         1     no  northwest   4239.89265
# 1325   61  male  33.535         0     no  northeast  13143.33665
# 1327   51  male  30.030         1     no  southeast   9377.90470
# 1329   52  male  38.600         2     no  southwest  10325.20600
# 1333   50  male  30.970         3     no  northwest  10600.54830
#
# [675 rows x 7 columns]

# %%
male_df=df[df['sex'] == 'male']

# %%
male_df
# Out:
#       age   sex     bmi  children smoker     region      charges
# 1      18  male  33.770         1     no  southeast   1725.55230
# 2      28  male  33.000         3     no  southeast   4449.46200
# 3      33  male  22.705         0     no  northwest  21984.47061
# 4      32  male  28.880         0     no  northwest   3866.85520
# 8      37  male  29.830         2     no  northeast   6406.41070
# ...   ...   ...     ...       ...    ...        ...          ...
# 1324   31  male  25.935         1     no  northwest   4239.89265
# 1325   61  male  33.535         0     no  northeast  13143.33665
# 1327   51  male  30.030         1     no  southeast   9377.90470
# 1329   52  male  38.600         2     no  southwest  10325.20600
# 1333   50  male  30.970         3     no  northwest  10600.54830
#
# [675 rows x 7 columns]

# %%
person_idf = df[(df['sex'] == 'male')|(df['sex'] == 'female')]

# %%
person_idf
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.rename(columns={'sex': 'gender'}, inplace=True)

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.drop(columns=['region'], axis=1,inplace=True)

# %%
df
# Out:
#       age  gender     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1337 rows x 6 columns]

# %%
num=df.select_dtypes(exclude='object')

# %%
num
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
char=df.select_dtypes(include='object')

# %%
char
# Out:
#       gender smoker
# 0     female    yes
# 1       male     no
# 2       male     no
# 3       male     no
# 4       male     no
# ...      ...    ...
# 1333    male     no
# 1334  female     no
# 1335  female     no
# 1336  female     no
# 1337  female    yes
#
# [1337 rows x 2 columns]

# %%
char['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()  
char['gender'] = le.fit_transform(char['gender']) 
char['smoker'] = le.fit_transform(char['smoker'])

# %%
char
# Out:
#       gender  smoker
# 0          0       1
# 1          1       0
# 2          1       0
# 3          1       0
# 4          1       0
# ...      ...     ...
# 1333       1       0
# 1334       0       0
# 1335       0       0
# 1336       0       0
# 1337       0       1
#
# [1337 rows x 2 columns]

# %%
clean_data=pd.concat([char,num],axis=1)

# %%
clean_data
# Out:
#       gender  smoker  age     bmi  children      charges
# 0          0       1   19  27.900         0  16884.92400
# 1          1       0   18  33.770         1   1725.55230
# 2          1       0   28  33.000         3   4449.46200
# 3          1       0   33  22.705         0  21984.47061
# 4          1       0   32  28.880         0   3866.85520
# ...      ...     ...  ...     ...       ...          ...
# 1333       1       0   50  30.970         3  10600.54830
# 1334       0       0   18  31.920         0   2205.98080
# 1335       0       0   18  36.850         0   1629.83350
# 1336       0       0   21  25.800         0   2007.94500
# 1337       0       1   61  29.070         0  29141.36030
#
# [1337 rows x 6 columns]

# %%
clean_data.to_csv('new_Cleaned_insurance.csv', index=False)
