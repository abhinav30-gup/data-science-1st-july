# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
data['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
data['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
data['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
plt.plot(data['total_bill'])
plt.show()

# %%
sns.lineplot(data['total_bill'])
plt.show()

# %%
sns.scatterplot(x='total_bill',y= 'tip',data=data)
plt.show()

# %%
sns.histplot(data['total_bill'])
plt.show()

# %%
plt.hist(data['total_bill'])
plt.show()

# %%
sns.kdeplot(data['total_bill'])
plt.show()

# %% [markdown]
# ## two type of plot
# * catplot
# * relayplot

# %%
sns.relplot(x='total_bill',y='tip', data=data)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip', data=data ,hue='time')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip', hue='time', style='smoker', data=data)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip', hue='time', style='smoker', kind='scatter',row='time',data=data)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip', hue='time', style='smoker', kind='scatter',data=data, col='smoker')
plt.show()

# %%
data['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.relplot(x='total_bill',y='tip', hue='time', style='smoker', kind='scatter',data=data,col='day')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.relplot(x='total_bill',y='tip',data=data)
plt.title('hm aaj seborn pad rahe h ')
plt.xlabel('x',fontsize=15, color='red')
plt.xlabel('y',fontsize=15, color='green')
plt.show()

# %%
sns.catplot(y='total_bill', x='day',data=data)
plt.show()

# %%
sns.catplot(y='total_bill', x='day', kind='swarm',data=data)
plt.show()

# %%
sns.catplot(y='total_bill', x='day', kind='strip',data=data)
plt.show()

# %%
sns.catplot(y='total_bill', x='day', kind='box',data=data)
plt.show()

# %%
sns.catplot(y='total_bill', x='day', kind='bar',data=data)
plt.show()

# %%
sns.catplot(y='total_bill', x='day', kind='violin',data=data)
plt.show()

# %%
sns.catplot(y='total_bill', x='day', kind='boxen',data=data)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='day',data=data)
plt.show()

# %%
sns.boxplot( x='day',y='total_bill',data=data)
plt.show()

# %%
sns.boxplot(y='total_bill',data=data)
plt.show()
