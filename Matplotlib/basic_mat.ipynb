# %% [markdown]
# # Matplotlib
# Matplotlib is a plotting library for Python that provides a comprehensive set of tools for creating high-quality
#
#  * It is widely used in data science and scientific computing for visualizing data and results. * 2D  and 3D plots, charts, and graphs. It is widely used in data analysis
#
#  * it is a popular Python library for creating static, animated, and interactive visualizations, such as line plots, bar charts, scatter plots, histograms, and more.

# %% [markdown]
# | *Category*     | *Details*                                                                                      |
# | ---------------- | ------------------------------------------------------------------------------------------------ |
# | *Definition*   | A Python 2D plotting library used for creating static, interactive, and animated visualizations. |
# | *Main Module*  | matplotlib.pyplot                                                                              |
# | *Developed In* | Python                                                                                           |
# | *Common Use*   | Data visualization in data science, machine learning, and research

# %% [markdown]
# | *Plot Type*  | *Description*                                                              |
# | -------------- | ---------------------------------------------------------------------------- |
# | Line Plot      | Shows trends over time or continuous data using lines.                       |
# | Bar Plot       | Displays categorical data with rectangular bars.                             |
# | Histogram      | Shows distribution of a dataset by grouping into bins.                       |
# | Scatter Plot   | Plots points for two variables to show relationships or clusters.            |
# | Pie Chart      | Represents data as slices of a pie to show proportions.                      |
# | Box Plot       | Shows data distribution with median, quartiles, and

# %%
import matplotlib.pyplot as plt
import numpy as np

x= [1,2,3,4,5]
y=[2,4,6,8,10]

plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x= [2,3,4,5,2]
y=[1,2,5,6,1]

plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoint =np.array([0,6])
ypoint =np.array([0,250])
plt.plot(xpoint,ypoint,'o')
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.plot(xpoint,marker='o')
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.plot(xpoint,marker='*')
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.plot(xpoint, 'o:b')
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.plot(xpoint,marker='o', ms=38)
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.plot(xpoint,marker='*', ms=38)
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.plot(xpoint,marker='*', ms=38 , mec='yellow')
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.plot(xpoint,marker='*', ms=38 , mec='red',mfc='purple')
plt.show()

# %%
xpoint =np.array([1,8,5,7])
plt.plot(x ,ls='dotted')
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.plot(xpoint, linewidth='5')
plt.show()

# %%
x =np.array([1,8,5,9])
y =np.array([2,3,8,5])
plt.plot(x)
plt.plot(y)
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.title("hm aaj metplotlib pad rahe h ")
plt.xlabel("x")
plt.xlabel("y")
plt.plot(xpoint, linewidth='5')
plt.show()

# %%
xpoint =np.array([1,8,5,9])
plt.title("hm aaj metplotlib pad rahe h ")
plt.xlabel("x")
plt.xlabel("y")
plt.plot(xpoint, linewidth='5')
plt.grid()
plt.show()

# %%
x =np.array([1,8,5,9])
y =np.array([2,3,8,5])
plt.plot(x)
plt.plot(y)
plt.grid()
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([1,4,8,6])
plt.subplot(1,2,1)
plt.plot(x,y)

x=np.array([1,2,3,4])
y=np.array([1,5,9,4])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
x= np.array([1,2,3,4,5])
y= np.array([1,5,3,7,8])
plt.scatter(x,y)
plt.show()

# %%
x= np.array([1,2,3,4,5])
y= np.array([1,5,3,7,8])
plt.scatter(x,y)
x =np.array([1,8,5,9])
y =np.array([2,3,8,5])
plt.scatter(x,y)
plt.show()

# %%
x= np.array([1,2,3,4,5])
y= np.array([1,5,3,7,8])
c=np.array(['red','green','black','blue','yellow'])
plt.scatter(x,y ,c=c)
plt.show()

# %%
x= np.array([1,2,3,4,5])
y= np.array([1,5,3,7,8])
c=np.array(['red','green','black','blue','yellow'])
plt.scatter(x,y ,c=c ,alpha=0.5)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c=c,alpha=0.5)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c, alpha=0.5 , cmap='coolwarm')
plt.colorbar()
plt.show()
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_2624\1272626596.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, s = sizes, c = c, alpha=0.5 , cmap='coolwarm')

# %% [markdown]
# ### bar plot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y,color='green')
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y, color='red', width=0.1)
plt.show()

# %% [markdown]
# ### hist plot

# %%
x=np.random.normal(170,10,250)

# %%
x
# Out:
# array([174.92427615, 170.50517836, 175.38536674, 151.42299393,
#        150.29372499, 150.67892978, 176.52712274, 163.88593   ,
#        173.48905431, 167.47510093, 190.88930971, 154.05125959,
#        181.74061133, 157.79825305, 182.63652956, 169.11497013,
#        166.98906781, 167.84975984, 176.35309846, 177.2776502 ,
#        176.70082023, 174.0054546 , 169.21469269, 178.53868492,
#        155.31115434, 185.83734075, 177.66912703, 151.47151458,
#        161.26209883, 179.36009848, 177.39687579, 157.08509035,
#        166.75806431, 176.44065848, 158.8367725 , 175.20661506,
#        173.85727969, 182.65040045, 161.34973403, 159.27673362,
#        168.86320179, 165.9338253 , 181.53313883, 164.78352704,
#        159.27542809, 155.72593725, 165.8106802 , 157.07059368,
#        179.04208025, 158.28284281, 178.62918966, 163.23541202,
#        176.61561258, 161.87932307, 173.89103731, 166.18722443,
#        169.82483773, 171.73514399, 175.80276195, 167.67227751,
# ...

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# ## pie

# %%
x=np.array([1,2,3,4,5])
plt.pie(x)
plt.show()

# %%
x=np.array([1,2,3,4])

labels =['apple', "banana", "cherry","data"]
plt.pie(x,labels=labels)
plt.show()

# %%
x=np.array([1,2,3,4])

labels =["apple", "banana", "cherry","data"]
myexplode=[0,0.2,0,0]
plt.pie(x,labels=labels , explode=myexplode)
plt.show()

# %%
x=np.array([1,2,3,4])

labels =["apple", "banana", "cherry","data"]
myexplode=[0,0.2,0,0]
plt.pie(x,labels=labels , explode=myexplode, shadow=2)
plt.show()

# %%
x=np.array([1,2,3,4])

labels =["apple", "banana", "cherry","data"]
myexplode=[0,0.2,0,0]
plt.pie(x,labels=labels , explode=myexplode, shadow=2, startangle=90)
plt.show()

# %%
x=np.array([1,2,3,4])

labels =["apple", "banana", "cherry","data"]
myexplode=[0,0.2,0,0]
plt.pie(x,labels=labels , explode=myexplode, shadow=2, startangle=90 , colors=c)
plt.show()

# %%
x=np.array([1,2,3,4])

labels =["apple", "banana", "cherry","data"]
myexplode=[0,0.2,0,0]
plt.pie(x,labels=labels , explode=myexplode, shadow=2, startangle=90 , colors=c, autopct='%1.1f%%')
plt.show()

# %%
x=np.array([1,2,3,4])

labels =["apple", "banana", "cherry","data"]
myexplode=[0,0.2,0,0]
c=['red','green','blue','yellow']
plt.pie(x,labels=labels , explode=myexplode, shadow=2, startangle=90 , colors=c, autopct='%1.1f%%')
plt.legend(title='my pie chart')
plt.show()
