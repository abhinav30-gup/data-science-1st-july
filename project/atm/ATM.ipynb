# %%
class ATM:
    def __init__(self,balance):
        self.balance= balance
        self.pin= "1325"

    def authentication(self):
        entered_pin= input("enter 4 digit pin: ")
        if entered_pin == self.pin:
            print("access successfuly done")
            return True
        else:
            print("incorrect pin. access denied")
        exit
          
    def deposit(self):
        amount=float(input("enter the deposit:"))
        if amount > 0:
            self.balance+=amount
            print(f"deposit successfully {amount:.2f}")


        else:
            print("invalid deposit amount")

    def withdraw(self):
        amount =float(input("enter the withdraw:"))
        if amount<=self.balance:
            self.balance-= amount
            print(f"withdraw successfully done {amount:.2f}")
        else:
            print("insufficient balance ")
        
    def check_balance(self):
        print(f"current balance is {self.balance:.2f}")

    def option(self):
        while True:
            print("\n1. Check Balance")
            print("2. Deposit")
            print("3. Withdraw")
            print("4. Exit")
            choice = int(input("Choose an option: "))
            if choice == 1:
                self.check_balance()
            elif choice == 2:
                self.deposit()
            elif choice == 3:
                self.withdraw()
            elif choice == 4:
                print("Thank you for using the ATM.")
                break
            else:
                print("Invalid option. Try again.")


atm=ATM(500000)

if atm.authentication():
    atm.option()
# Out:
# access successfuly done
#
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# current balance is 500000.00
#
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# deposit successfully 5000.00
#
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# withdraw successfully done 5000.00
#
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Thank you for using the ATM.
